# %%
# !pip install pandas-datareader
# !pip install fix_yahoo_finance
import numpy as np
import pandas as pd
import pandas_datareader
from pandas_datareader import data as pdr
import fix_yahoo_finance

import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('username', 'key')
# Out:
# Requirement already satisfied: pandas-datareader in /Users/missy/anaconda3/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied: pandas>=0.19.2 in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas-datareader) (0.23.0)
# Requirement already satisfied: wrapt in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas-datareader) (1.10.11)
# Requirement already satisfied: requests>=2.3.0 in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas-datareader) (2.18.4)
# Requirement already satisfied: lxml in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas-datareader) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas>=0.19.2->pandas-datareader) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas>=0.19.2->pandas-datareader) (2018.4)
# Requirement already satisfied: numpy>=1.9.0 in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas>=0.19.2->pandas-datareader) (1.14.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (2018.4.16)
# Requirement already satisfied: six>=1.5 in /Users/missy/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.19.2->pandas-datareader) (1.11.0)
# Requirement already satisfied: fix_yahoo_finance in /Users/missy/anaconda3/lib/python3.6/site-packages (0.0.22)
# Requirement already satisfied: requests in /Users/missy/anaconda3/lib/python3.6/site-packages (from fix_yahoo_finance) (2.18.4)
# Requirement already satisfied: numpy in /Users/missy/anaconda3/lib/python3.6/site-packages (from fix_yahoo_finance) (1.14.3)
# Requirement already satisfied: pandas in /Users/missy/anaconda3/lib/python3.6/site-packages (from fix_yahoo_finance) (0.23.0)
# Requirement already satisfied: multitasking in /Users/missy/anaconda3/lib/python3.6/site-packages (from fix_yahoo_finance) (0.0.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests->fix_yahoo_finance) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests->fix_yahoo_finance) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests->fix_yahoo_finance) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/missy/anaconda3/lib/python3.6/site-packages (from requests->fix_yahoo_finance) (2018.4.16)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas->fix_yahoo_finance) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /Users/missy/anaconda3/lib/python3.6/site-packages (from pandas->fix_yahoo_finance) (2018.4)
# Requirement already satisfied: six>=1.5 in /Users/missy/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->fix_yahoo_finance) (1.11.0)

# %%
ticker = "^GSPC"
sma_range = 200
log_yaxis = False

# Specify a bit more time because rolling average needs backward data
date_start = "2000-01-01"
date_range_start = "2001-01-01"
date_end = "2018-10-25"

chart_filename = ticker + " " + date_start + " to " + date_end
df = pdr.get_data_yahoo(ticker, date_start, date_end)

# %%
trace1 = Candlestick(
    x = df.index,
    open = df["Open"],
    high = df["High"],
    low = df["Low"],
    close = df["Close"],
    name = ticker,
    )

data = [trace1]

for i in range(5, (sma_range + 1), 5):
    sma = Scatter(
        x = df.index,
        y = df["Close"].rolling(i).mean(), # Pandas SMA
        name = "SMA" + str(i),
        mode = "lines",
        line = dict(color = "#6f3daa"),
        opacity = 0.7,
        visible = False
    )
    data.append(sma)

# %%
sliders = dict(

    # GENERAL
    steps = [],
    currentvalue = dict(
        font = dict(size = 16),
        prefix = "SMA: ",
        xanchor = "left",
    ),

    # PLACEMENT
    x = 0.15,
    y = 0,
    len = 0.85,
    pad = dict(t = 0, b = 0),
    yanchor = "bottom",
    xanchor = "left",
)

for i in range((sma_range // 5) + 1):

    step = dict(
        method = "restyle",
        label = str(i * 5),
        value = str(i * 5),
        args = ["visible", [False] * ((sma_range // 5) + 1)], # Sets all to false
    )

    step['args'][1][0] = True # Main trace
    step['args'][1][i] = True # Selected trace through slider
    sliders["steps"].append(step)

updatemenus = dict(

    # GENERAL
    type = "buttons",
    showactive = False,
    x = 0,
    y = 0,
    pad = dict(t = 0, b = 0),
    yanchor = "bottom",
    xanchor = "left",

    # BUTTONS
    buttons=[
        dict(
            method = "restyle",
            label = "Golden Cross",
            args = ["visible", [False] * ((sma_range // 5) + 1)],
        ),
        dict(
            method = "restyle",
            label = "Common SMAs",
            args = ["visible", [False] * ((sma_range // 5) + 1)],
        )
    ],

)

# Set all traces to invisible, then toggle these ones selectively

# Golden cross refers to the 50SMA and 200SMA cross
# and is an indicator of long term market support
updatemenus["buttons"][0]["args"][1][0] = True # Main plot
updatemenus["buttons"][0]["args"][1][10] = True # SMA 50
updatemenus["buttons"][0]["args"][1][40] = True # SMA 200

# Here are other common SMAs used in trading (5, 10, 20, 50 SMA)
updatemenus["buttons"][1]["args"][1][0] = True # Main plot
updatemenus["buttons"][1]["args"][1][1] = True # SMA 5
updatemenus["buttons"][1]["args"][1][2] = True # etc.
updatemenus["buttons"][1]["args"][1][4] = True
updatemenus["buttons"][1]["args"][1][10] = True

# %%
layout = dict(

    title = chart_filename,

    # GENERAL LAYOUT
    width = 1080,
    height = 720,
    autosize = True,
    font = dict(
        family = "Overpass",
        size = 12,
    ),
    margin = dict(
        t = 80,
        l = 50,
        b = 50,
        r = 50,
        pad = 5,
    ),
    showlegend = False,

    # ANIMATIONS
    sliders = [sliders],
    updatemenus = [updatemenus],

    # COLOR THEME
    plot_bgcolor = "#FFFFFF",
    paper_bgcolor = "#FAFAFA",

    # LINEAR PLOTS
    xaxis = dict(

        # RANGE
        range = [date_range_start, date_end],

        # RANGE SLIDER AND SELECTOR
        rangeslider = dict(
            bordercolor = "#FFFFFF",
            bgcolor = "#FFFFFF",
            thickness = 0.1,
        ),

        # Buttons for date range (1D, 5D, 1M, 3M, 6M, 1Y, 2Y, 5Y, Max, YTD)
        rangeselector = dict(
            activecolor = "#888888",
            bgcolor = "#DDDDDD",
            buttons = [
                dict(count = 1, step = "day", stepmode = "backward", label = "1D"),
                dict(count = 5, step = "day", stepmode = "backward", label = "5D"),
                dict(count = 1, step = "month", stepmode = "backward", label = "1M"),
                dict(count = 3, step = "month", stepmode = "backward", label = "3M"),
                dict(count = 6, step = "month", stepmode = "backward", label = "6M"),
                dict(count = 1, step = "year", stepmode = "backward", label = "1Y"),
                dict(count = 2, step = "year", stepmode = "backward", label = "2Y"),
                dict(count = 5, step = "year", stepmode = "backward", label = "5Y"),
                dict(count = 1, step = "all", stepmode = "backward", label = "MAX"),
                dict(count = 1, step = "year", stepmode = "todate", label = "YTD"),
            ]
        ),

    ),
    yaxis = dict(
        fixedrange = False,
        tickprefix = "$",
        type = "linear",
        domain = [0.25, 1],
    ),

)

if log_yaxis: layout["yaxis"]["type"] = "log"

# %%
figure = dict(data=data, layout=layout)
py.iplot(figure, filename=chart_filename, fileopt="overwrite")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~missywong/26.embed" height="720px" width="1080px"></iframe>
